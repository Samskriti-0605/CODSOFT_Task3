# %% [markdown]
# <a href="https://colab.research.google.com/github/Samskriti-0605/CODSOFT_Task3/blob/main/CREDIT%20CARD%20FRAUD%20DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as num_py
import pandas as pd_lib
import matplotlib.pyplot as plot
import seaborn as sea_lib
# %matplotlib inline

# %%
creditCard = pd_lib.read_csv("creditcard.csv")

# %%
creditCard
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 27814  34711  1.443955 -1.052462 -0.141721 -1.564017 -0.966274 -0.333886
# 27815  34711 -0.263364  0.931818  1.193111 -0.507924  0.862019  0.249381
# 27816  34712  0.976345 -1.024867  0.978714  0.639442 -1.413711  0.311635
# 27817  34712  1.464604 -0.437919 -0.018869 -1.057177 -0.154243  0.251215
# 27818     34       NaN       NaN       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
creditCard.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
creditCard.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 27814  34711  1.443955 -1.052462 -0.141721 -1.564017 -0.966274 -0.333886
# 27815  34711 -0.263364  0.931818  1.193111 -0.507924  0.862019  0.249381
# 27816  34712  0.976345 -1.024867  0.978714  0.639442 -1.413711  0.311635
# 27817  34712  1.464604 -0.437919 -0.018869 -1.057177 -0.154243  0.251215
# 27818     34       NaN       NaN       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 27814 -0.777060  0.023616 -2.168826  ... -0.479940 -1.165220  0.155226
# 27815  0.815449 -0.090801 -0.520583  ... -0.310112 -0.648621 -0.253746
# 27816 -0.909035  0.232423 -0.493025  ... -0.279978 -0.599463 -0.081403
# 27817 -0.584866 -0.025483 -0.841369  ... -0.148384 -0.454571 -0.019732
# 27818       NaN       NaN       NaN  ...       NaN       NaN       NaN
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
 creditCard.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
round(creditCard.describe(),2).T
# Out:
#           count      mean       std    min      25%       50%       75%  \
# Time    27819.0  20434.63  11866.06   0.00  9037.50  24675.00  31319.00
# V1      27818.0     -0.22      1.87 -30.55    -0.95     -0.26      1.17
# V2      27818.0      0.15      1.55 -40.98    -0.42      0.16      0.80
# V3      27818.0      0.72      1.65 -31.10     0.27      0.86      1.48
# V4      27818.0      0.22      1.43  -5.17    -0.69      0.20      1.10
# V5      27818.0     -0.20      1.43 -42.15    -0.79     -0.23      0.32
# V6      27818.0      0.08      1.33 -23.50    -0.66     -0.17      0.47
# V7      27818.0     -0.13      1.31 -26.55    -0.60     -0.07      0.45
# V8      27818.0      0.03      1.31 -41.48    -0.16      0.03      0.29
# V9      27818.0      0.39      1.26  -7.18    -0.42      0.31      1.15
# V10     27818.0     -0.13      1.17 -14.17    -0.60     -0.18      0.31
# V11     27818.0      0.54      1.16  -2.90    -0.29      0.52      1.30
# ...

# %%
creditCard.isna().sum()
# Out:
# Time      0
# V1        1
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
creditCard.duplicated().sum()
# Out:
# 111

# %%
creditCard.drop_duplicates()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 27814  34711  1.443955 -1.052462 -0.141721 -1.564017 -0.966274 -0.333886
# 27815  34711 -0.263364  0.931818  1.193111 -0.507924  0.862019  0.249381
# 27816  34712  0.976345 -1.024867  0.978714  0.639442 -1.413711  0.311635
# 27817  34712  1.464604 -0.437919 -0.018869 -1.057177 -0.154243  0.251215
# 27818     34       NaN       NaN       NaN       NaN       NaN       NaN
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
creditCard["Class"].value_counts()
# Out:
# Class
# 0.0    27725
# 1.0       93
# Name: count, dtype: int64

# %%
import seaborn as sea_lib # assuming seaborn is imported as sea_lib
import matplotlib.pyplot as plot # Assuming matplotlib.pyplot is imported as plot

ax = sea_lib.countplot(data=creditCard, x="Class", width=0.4) # Change 'class' to 'Class'
ax.set_title("Class Distribution")
ax.set_xlabel("type of transactions ")
ax.set_ylabel("number of transactions")
for i in ax.containers:
    ax.bar_label(i)
plot.show()

# %%
plot.figure(figsize=(20,12))
sea_lib.heatmap(creditCard.corr(),annot=True,fmt='.2f')
for i in range(creditCard.shape[1] + 1):
  ax.axvline(i,color='white',lw=2)
  ax.axhline(i,color='white',lw=2)
plot.show()

# %%
def split_data(creditCard):
  legit = creditCard[creditCard["Class"]==1]
  fraud= creditCard[creditCard["Class"]==0]
  return legit,fraud
legit_new,fraud_new = split_data(creditCard)

# %%
legit_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 150 entries, 541 to 50537
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    150 non-null    int64
#  1   V1      150 non-null    float64
#  2   V2      150 non-null    float64
#  3   V3      150 non-null    float64
#  4   V4      150 non-null    float64
#  5   V5      150 non-null    float64
#  6   V6      150 non-null    float64
#  7   V7      150 non-null    float64
#  8   V8      150 non-null    float64
#  9   V9      150 non-null    float64
#  10  V10     150 non-null    float64
#  11  V11     150 non-null    float64
#  12  V12     150 non-null    float64
#  13  V13     150 non-null    float64
#  14  V14     150 non-null    float64
#  15  V15     150 non-null    float64
#  16  V16     150 non-null    float64
#  17  V17     150 non-null    float64
#  18  V18     150 non-null    float64
#  19  V19     150 non-null    float64
# ...

# %%
fraud_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51440 entries, 0 to 51589
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    51440 non-null  int64
#  1   V1      51440 non-null  float64
#  2   V2      51440 non-null  float64
#  3   V3      51440 non-null  float64
#  4   V4      51440 non-null  float64
#  5   V5      51440 non-null  float64
#  6   V6      51440 non-null  float64
#  7   V7      51440 non-null  float64
#  8   V8      51440 non-null  float64
#  9   V9      51440 non-null  float64
#  10  V10     51440 non-null  float64
#  11  V11     51440 non-null  float64
#  12  V12     51440 non-null  float64
#  13  V13     51440 non-null  float64
#  14  V14     51440 non-null  float64
#  15  V15     51440 non-null  float64
#  16  V16     51440 non-null  float64
#  17  V17     51440 non-null  float64
#  18  V18     51440 non-null  float64
#  19  V19     51440 non-null  float64
# ...

# %%
legit_new.describe().T
# Out:
#         count          mean           std         min           25%  \
# Time    150.0  27111.653333  12975.069422  406.000000  14568.250000
# V1      150.0     -7.605033      8.414781  -30.552380    -14.108675
# V2      150.0      5.403059      4.313544   -5.198360      2.440366
# V3      150.0    -10.281767      8.667429  -31.103685    -16.341798
# V4      150.0      5.877956      2.827742   -1.255593      3.872083
# V5      150.0     -5.631727      6.524172  -22.105532    -10.142429
# V6      150.0     -2.260874      1.533029   -4.977692     -3.143725
# V7      150.0     -7.999087      6.893834  -21.922811    -14.548283
# V8      150.0      3.694993      5.524874   -3.277535      0.164206
# V9      150.0     -3.548144      2.610286   -9.283925     -5.683827
# V10     150.0     -7.484218      4.522633  -18.271168    -11.692744
# V11     150.0      5.388025      2.773111   -0.473852      3.604456
# V12     150.0     -8.617897      4.423908  -17.769143    -12.107396
# ...

# %%
new_legit_new = legit_new.sample(n=492, replace=True)
# Set replace to True to sample with replacement

# %%
# Print or inspect the shape of 'new_legit_new' to verify
print(new_legit_new)
# Out:
#         Time         V1        V2         V3        V4         V5        V6  \
# 42958  41313 -13.897206  6.344280 -14.281666  5.581009 -12.887133 -3.146176
# 6472    7740   1.023874  2.001485  -4.769752  3.819195  -1.271754 -1.734662
# 18773  29753   0.269614  3.549755  -5.810353  5.809370   1.538808 -2.269219
# 44556  41991  -4.566342  3.353451  -4.572028  3.616119  -2.493138 -1.090000
# 43681  41607 -18.247513  8.713250 -17.880127  9.249459 -14.541213 -1.911564
# ...      ...        ...       ...        ...       ...        ...       ...
# 4920    4462  -2.303350  1.759247  -0.359745  2.330243  -0.821628 -0.075788
# 10630  17838  -5.187878  6.967709 -13.510931  8.617895 -11.214422  0.672248
# 44556  41991  -4.566342  3.353451  -4.572028  3.616119  -2.493138 -1.090000
# 30384  35899  -2.857170  4.045601  -4.197299  5.487199  -3.070776 -1.422686
# 44223  41851 -19.139733  9.286847 -20.134992  7.818673 -15.652208 -1.668348
#
# ...

# %%
combine_new = pd_lib.concat([new_legit_new,fraud_new],axis=0)

# %%
combine_new
# Out:
#         Time         V1        V2         V3        V4         V5        V6  \
# 42958  41313 -13.897206  6.344280 -14.281666  5.581009 -12.887133 -3.146176
# 6472    7740   1.023874  2.001485  -4.769752  3.819195  -1.271754 -1.734662
# 18773  29753   0.269614  3.549755  -5.810353  5.809370   1.538808 -2.269219
# 44556  41991  -4.566342  3.353451  -4.572028  3.616119  -2.493138 -1.090000
# 43681  41607 -18.247513  8.713250 -17.880127  9.249459 -14.541213 -1.911564
# ...      ...        ...       ...        ...       ...        ...       ...
# 51585  45022   1.096818  0.358443   1.693603  2.778800  -0.838672 -0.008694
# 51586  45023  -2.943382 -2.332451   2.568959  0.747114   2.083550 -1.319267
# 51587  45024  -1.278283 -3.726046  -0.902718  2.796542  -1.750987  0.199763
# 51588  45024  -0.852261  0.886192  -0.378032 -1.142044   1.880941  3.505875
# 51589  45024  -0.447740  0.775759   1.586053  0.227702  -0.270962 -0.539013
#
# ...

# %%
combine_new["Class"].value_counts()
# Out:
# Class
# 0.0    51440
# 1.0      492
# Name: count, dtype: int64

# %%
ax = sea_lib.countplot(data=combine_new, x="Class", width=0.4) # Change 'class' to 'Class'
ax = sea_lib.countplot(data=combine_new, x="Class", width=0.4) # Change 'class' to 'Class'
ax.set_title(" Distribution of Transactions")
ax.set_xlabel("type of transactions ")
ax.set_ylabel("number of transactions")
for i in ax.containers:
              ax.bar_label(i)
plot.show()

plot.show()

# %%
x = combine_new.drop(columns="Class",axis=1)
y = combine_new["Class"]
#

# %%
x
# Out:
#         Time         V1        V2         V3        V4         V5        V6  \
# 42958  41313 -13.897206  6.344280 -14.281666  5.581009 -12.887133 -3.146176
# 6472    7740   1.023874  2.001485  -4.769752  3.819195  -1.271754 -1.734662
# 18773  29753   0.269614  3.549755  -5.810353  5.809370   1.538808 -2.269219
# 44556  41991  -4.566342  3.353451  -4.572028  3.616119  -2.493138 -1.090000
# 43681  41607 -18.247513  8.713250 -17.880127  9.249459 -14.541213 -1.911564
# ...      ...        ...       ...        ...       ...        ...       ...
# 51585  45022   1.096818  0.358443   1.693603  2.778800  -0.838672 -0.008694
# 51586  45023  -2.943382 -2.332451   2.568959  0.747114   2.083550 -1.319267
# 51587  45024  -1.278283 -3.726046  -0.902718  2.796542  -1.750987  0.199763
# 51588  45024  -0.852261  0.886192  -0.378032 -1.142044   1.880941  3.505875
# 51589  45024  -0.447740  0.775759   1.586053  0.227702  -0.270962 -0.539013
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)
#

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x_train)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 20376  30999 -0.563227 -0.838910  1.033207 -1.254586 -1.232494  0.149402
# 25627  33694 -1.996517  1.767224  0.501458 -1.768733 -0.424154 -0.244882
# 5119    4807 -1.716096  0.990185  1.669881 -1.187550  0.154523 -0.204359
# 47820  43375  1.266737 -1.475689  0.327613 -1.232232 -1.526951 -0.200939
# 8867   12145  1.079762  0.137146  0.486058  1.638442 -0.164635 -0.129313
# ...      ...       ...       ...       ...       ...       ...       ...
# 2509    2085 -1.864408 -0.582157  0.641907 -1.582686 -0.576913 -0.528672
# 23636  32849  1.051521 -0.077315  1.379551  1.220922 -0.781259  0.486727
# 21597  31756  1.171236 -0.041428  0.780442  0.843365 -0.869942 -0.855891
# 46930  42992  1.390834 -1.320231  0.514912 -1.475554 -1.696711 -0.426602
# 46518  42818  1.109545  0.109412  0.273952  1.212018  0.077422  0.346030
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(x_train.shape,x_test.shape)
# Out:
# (41545, 30) (10387, 30)

# %%
from sklearn.linear_model import LogisticRegression # Import the LogisticRegression class

model = LogisticRegression() # Use the correct class name: LogisticRegression

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score # Import accuracy_score from sklearn.metrics

model = LogisticRegression()

# Fit the model to your training data before making predictions.
model.fit(x_train, y_train) # This line trains the model

x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(x_train_prediction, y_train) # Now accuracy_score is defined
print(f"The model's training data accuracy is: {round(training_data_accuracy*100,2)}%")
# Out:
# The model's training data accuracy is: 99.67%
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(x_test_prediction, y_test)
print(f"The model's test data accuracy is: {round(test_data_accuracy*100,2)}%")
# Out:
# The model's test data accuracy is: 99.74%

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay # Import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

ax = ConfusionMatrixDisplay.from_predictions(y_test, x_test_prediction)
plt.show() # Add this line to display the plot if it's not showing automatically
